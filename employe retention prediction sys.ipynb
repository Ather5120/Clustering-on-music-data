# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

#sktlearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('HR_comma_sep.csv')
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
left =data[data.left==0]
left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# ...                   ...              ...             ...
# 14206                0.90             0.55               3
# 14207                0.74             0.95               5
# 14208                0.85             0.54               3
# 14209                0.33             0.65               3
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2000                    215                   3              0     0
# 2001                    202                   3              0     0
# ...

# %%
stay=data[data.left==1]
stay
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
data.groupby('left').mean(numeric_only=True)
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
sns.barplot(x='salary', y='left', data=data, ci=None)
# Out:
# /tmp/ipykernel_11303/3250776617.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='salary', y='left', data=data, ci=None)
# <Axes: xlabel='salary', ylabel='left'>

# %%
# top_brand=upd_data['Brand'].unique()
plt.figure(figsize=(10, 6))
sns.countplot(data=data,x='salary',hue='left')
# top_brand
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
# top_brand=upd_data['Brand'].unique()
plt.figure(figsize=(12, 8))
sns.countplot(data=data,x='Department',hue='left')
# top_brand
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
training_data=data[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
training_data
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
data_with_dummies=pd.get_dummies(training_data.salary,prefix='salary',dtype=int)
data_with_dummies
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
data_with_dummy_salaries=pd.concat((training_data,data_with_dummies),axis="columns")
data_with_dummy_salaries
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  salary_high  salary_low  salary_medium
# 0         low            0           1              0
# ...

# %%
# data_with_dummy_salaries.drop('salary',axis="columns",inplace=True)
data_with_dummy_salaries
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  salary_high  salary_low  salary_medium
# 0         low            0           1              0
# ...

# %%
x=data_with_dummy_salaries
x
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  salary_high  salary_low  salary_medium
# 0         low            0           1              0
# ...

# %%
y=data.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=2)

# %%
lgr= LogisticRegression()
lgr.fit(x,y)
lgr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_11303/3452254757.py in ?()
#       1 lgr= LogisticRegression()
# ----> 2 lgr.fit(x,y)
#       3 lgr
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py in ?(self, X, y, sample_weight)
#    1203             _dtype = np.float64
#    1204         else:
#    1205             _dtype = [np.float64, np.float32]
#    1206
# -> 1207         X, y = self._validate_data(
#    1208             X,
#    1209             y,
# ...

# %%
y_pred=lgr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y_pred=lgr.predict(x_test)
#
# NameError: name 'lgr' is not defined

# %%
y_test
# Out:
# 7231     0
# 12081    1
# 5364     0
# 14589    1
# 2353     0
#         ..
# 14608    1
# 1699     1
# 6822     0
# 10151    0
# 1034     1
# Name: left, Length: 1500, dtype: int64

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7746666666666666

# %%
lgr.predict([[0,2000,0,0,0,1]])
# Out:
# /home/ather/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
